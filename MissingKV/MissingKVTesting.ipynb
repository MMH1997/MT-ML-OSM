# %% [markdown]
# ### We import the libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### We load the datasets of the tags.

# %%
buiBarcelona = pd.read_csv('buildingBarcelona.csv', delimiter=";", encoding='latin-1')
buiBarcelona = buiBarcelona.iloc[:,1:]
ameBarcelona = pd.read_csv('amenityBarcelona.csv', delimiter=";", encoding='latin-1')
ameBarcelona = ameBarcelona.iloc[:,1:]
# touBarcelona = pd.read_csv('tourismBarcelona.csv', delimiter=";", encoding='latin-1')
# touBarcelona = touBarcelona.iloc[:,1:]
higBarcelona = pd.read_csv('highwayBarcelona.csv', delimiter=";", encoding='latin-1')
higBarcelona = higBarcelona.iloc[:,1:]
Barcelona = buiBarcelona.append(ameBarcelona, ignore_index=True)
# Barcelona = Barcelona.append(touBarcelona, ignore_index = True)
Barcelona = Barcelona.append(higBarcelona, ignore_index = True)
Barcelona
# Out:
#        alpha            alphap        beta                   Role
# 0   building  addr:housenumber         yes     Useful Combination
# 1   building       addr:street         yes     Useful Combination
# 2   building   building:levels  apartments     Useful Combination
# 3   building  addr:housenumber  apartments     Useful Combination
# 4   building     addr:postcode  apartments     Useful Combination
# ..       ...               ...         ...                    ...
# 58   highway               lit     footway     Useful Combination
# 59   highway           surface     footway     Useful Combination
# 60   highway             layer     footway  NonUseful Combination
# 61   highway           name:es     footway     Useful Combination
# 62   highway           footway     footway   Required Combination
#
# [63 rows x 4 columns]

# %%
buiBoston = pd.read_csv('buildingBoston.csv', delimiter=";", encoding='latin-1')
buiBoston = buiBoston.iloc[:,1:]
ameBoston = pd.read_csv('amenityBoston.csv', delimiter=";", encoding='latin-1')
ameBoston = ameBoston.iloc[:,1:]
touBoston = pd.read_csv('tourismBoston.csv', delimiter=";", encoding='latin-1')
touBoston = touBoston.iloc[:,1:]
higBoston = pd.read_csv('highwayBoston.csv', delimiter=";", encoding='latin-1')
higBoston = higBoston.iloc[:,1:]
Boston = buiBoston.append(ameBoston, ignore_index=True)
Boston = Boston.append(touBoston, ignore_index = True)
Boston = Boston.append(higBoston, ignore_index = True)
Boston
# Out:
#         alpha            alphap   beta                   Role
# 0    building        addr:state    yes     Useful Combination
# 1    building              name    yes     Useful Combination
# 2    building            source    yes     Useful Combination
# 3    building         addr:city    yes     Useful Combination
# 4    building  addr:housenumber    yes     Useful Combination
# ..        ...               ...    ...                    ...
# 177   highway               lit  steps   Required Combination
# 178   highway           surface  steps   Required Combination
# 179   highway             width  steps   Required Combination
# 180   highway            indoor  steps  NonUseful Combination
# 181   highway        step_count  steps     Useful Combination
#
# [182 rows x 4 columns]

# %%
buiBrussel = pd.read_csv('buildingBrussel.csv', delimiter=";", encoding='latin-1')
buiBrussel = buiBrussel.iloc[:,1:]
ameBrussel = pd.read_csv('amenityBrussel.csv', delimiter=";", encoding='latin-1')
ameBrussel = ameBrussel.iloc[:,1:]
touBrussel = pd.read_csv('tourismBrussel.csv', delimiter=";", encoding='latin-1')
touBrussel = touBrussel.iloc[:,1:]
higBrussel = pd.read_csv('highwayBrussel.csv', delimiter=";", encoding='latin-1')
higBrussel = higBrussel.iloc[:,1:]
Brussel = buiBrussel.append(ameBrussel, ignore_index=True)
Brussel = Brussel.append(touBrussel, ignore_index = True)
Brussel = Brussel.append(higBrussel, ignore_index = True)
Brussel
# Out:
#         alpha         alphap     beta                  Role
# 0    building      addr:city      yes    Useful Combination
# 1    building  addr:postcode      yes    Useful Combination
# 2    building    addr:street      yes    Useful Combination
# 3    building           name      yes    Useful Combination
# 4    building        name:fr      yes    Useful Combination
# ..        ...            ...      ...                   ...
# 204   highway        name:nl  footway    Useful Combination
# 205   highway        surface  footway    Useful Combination
# 206   highway       wikidata  footway    Useful Combination
# 207   highway         tunnel  footway    Useful Combination
# 208   highway        footway  footway  Required Combination
#
# [209 rows x 4 columns]

# %%
buiElCairo = pd.read_csv('buildingElCairo.csv', delimiter=";", encoding='latin-1')
buiElCairo = buiElCairo.iloc[:,1:]
ameElCairo = pd.read_csv('amenityElCairo.csv', delimiter=";", encoding='latin-1')
ameElCairo = ameElCairo.iloc[:,1:]
touElCairo = pd.read_csv('tourismElCairo.csv', delimiter=";", encoding='latin-1')
touElCairo = touElCairo.iloc[:,1:]
higElCairo = pd.read_csv('highwayElCairo.csv', delimiter=";", encoding='latin-1')
higElCairo = higElCairo.iloc[:,1:]
ElCairo = ameElCairo.append(higElCairo, ignore_index = True)
ElCairo = ElCairo.append(buiElCairo, ignore_index = True)
ElCairo = ElCairo.append(touElCairo, ignore_index = True)

# %%
buiElCairo2 = pd.read_csv('buildingElCairo2.csv', delimiter=";", encoding='latin-1')
buiElCairo2 = buiElCairo2.iloc[:,1:]
ameElCairo2 = pd.read_csv('amenityElCairo2.csv', delimiter=";", encoding='latin-1')
ameElCairo2 = ameElCairo2.iloc[:,1:]
touElCairo2 = pd.read_csv('tourismElCairo2.csv', delimiter=";", encoding='latin-1')
touElCairo2 = touElCairo2.iloc[:,1:]
higElCairo2 = pd.read_csv('highwayElCairo2.csv', delimiter=";", encoding='latin-1')
higElCairo2 = higElCairo2.iloc[:,1:]
ElCairo2 = ameElCairo2.append(higElCairo2, ignore_index = True)
ElCairo2 = ElCairo2.append(buiElCairo2, ignore_index = True)
ElCairo2 = ElCairo2.append(touElCairo2, ignore_index = True)
ElCairo2
# Out:
#        alpha           alphap              beta                   Role
# 0    amenity         building  place_of_worship  NonUseful Combination
# 1    amenity             name              cafe     Useful Combination
# 2    amenity          name:en              cafe     Useful Combination
# 3    amenity        addr:city              cafe     Useful Combination
# 4    amenity          name:en         fast_food     Useful Combination
# ..       ...              ...               ...                    ...
# 178  tourism          name:en             hotel     Useful Combination
# 179  tourism          website             hotel     Useful Combination
# 180  tourism  internet_access             hotel     Useful Combination
# 181  tourism           source             hotel     Useful Combination
# 182  tourism         building             hotel  NonUseful Combination
#
# [183 rows x 4 columns]

# %%
buiLaHabana = pd.read_csv('buildingLaHabana.csv', delimiter=";", encoding='latin-1')
buiLaHabana = buiLaHabana.iloc[:,1:]
ameLaHabana = pd.read_csv('amenityLaHabana.csv', delimiter=";", encoding='latin-1')
ameLaHabana = ameLaHabana.iloc[:,1:]
touLaHabana = pd.read_csv('tourismLaHabana.csv', delimiter=";", encoding='latin-1')
touLaHabana = touLaHabana.iloc[:,1:]
higLaHabana = pd.read_csv('highwayLaHabana.csv', delimiter=";", encoding='latin-1')
higLaHabana = higLaHabana.iloc[:,1:]
LaHabana = buiLaHabana.append(ameLaHabana, ignore_index=True)
LaHabana = LaHabana.append(touLaHabana, ignore_index = True)
LaHabana = LaHabana.append(higLaHabana, ignore_index = True)
LaHabana
# Out:
#         alpha           alphap     beta                   Role
# 0    building      addr:street      yes     Useful Combination
# 1    building             name      yes     Useful Combination
# 2    building  building:levels      yes     Useful Combination
# 3    building           office      yes  NonUseful Combination
# 4    building          amenity      yes  NonUseful Combination
# ..        ...              ...      ...                    ...
# 170   highway          surface  service     Useful Combination
# 171   highway           access  service     Useful Combination
# 172   highway           source  service     Useful Combination
# 173   highway          service  service   Required Combination
# 174   highway          footway  footway   Required Combination
#
# [175 rows x 4 columns]

# %%
buiLuanda = pd.read_csv('buildingLuanda.csv', delimiter=";", encoding='latin-1')
buiLuanda = buiLuanda.iloc[:,1:]
ameLuanda = pd.read_csv('amenityLuanda.csv', delimiter=";", encoding='latin-1')
ameLuanda = ameLuanda.iloc[:,1:]
touLuanda = pd.read_csv('tourismLuanda.csv', delimiter=";", encoding='latin-1')
touLuanda = touLuanda.iloc[:,1:]
higLuanda = pd.read_csv('highwayLuanda.csv', delimiter=";", encoding='latin-1')
higLuanda = higLuanda.iloc[:,1:]
Luanda = buiLuanda.append(ameLuanda, ignore_index=True)
Luanda = Luanda.append(touLuanda, ignore_index = True)
Luanda = Luanda.append(higLuanda, ignore_index = True)
Luanda
# Out:
#         alpha       alphap          beta                   Role
# 0    building  addr:street           yes     Useful Combination
# 1    building         name           yes     Useful Combination
# 2    building    addr:city           yes     Useful Combination
# 3    building         shop           yes  NonUseful Combination
# 4    building      name:de           yes     Useful Combination
# ..        ...          ...           ...                    ...
# 134   highway     old_name  unclassified     Useful Combination
# 135   highway       oneway  unclassified     Useful Combination
# 136   highway      surface  unclassified     Useful Combination
# 137   highway       source  unclassified     Useful Combination
# 138   highway      surface       service     Useful Combination
#
# [139 rows x 4 columns]

# %%
buiOtawa = pd.read_csv('buildingOtawa.csv', delimiter=";", encoding='latin-1')
buiOtawa = buiOtawa.iloc[:,1:]
ameOtawa = pd.read_csv('amenityOtawa.csv', delimiter=";", encoding='latin-1')
ameOtawa = ameOtawa.iloc[:,1:]
# touOtawa = pd.read_csv('tourismOtawa.csv', delimiter=";", encoding='latin-1')
# touOtawa = touOtawa.iloc[:,1:]
higOtawa = pd.read_csv('highwayOtawa.csv', delimiter=";", encoding='latin-1')
higOtawa = higOtawa.iloc[:,1:]
Otawa = buiOtawa.append(ameOtawa, ignore_index=True)
# Otawa = Otawa.append(touOtawa, ignore_index = True)
Otawa = Otawa.append(higOtawa, ignore_index = True)
Otawa
# Out:
#        alpha                 alphap             beta                   Role
# 0   building                   name       apartments     Useful Combination
# 1   building               operator       apartments  NonUseful Combination
# 2   building              mapillary       apartments     Useful Combination
# 3   building          addr:postcode       apartments     Useful Combination
# 4   building            survey:date       apartments     Useful Combination
# 5   building       addr:housenumber              yes     Useful Combination
# 6   building            addr:street              yes     Useful Combination
# 7   building        building:levels              yes     Useful Combination
# 8   building                   name              yes     Useful Combination
# 9   building              mapillary              yes     Useful Combination
# 10  building            survey:date              yes     Useful Combination
# 11  building                 office              yes  NonUseful Combination
# 12  building                amenity              yes  NonUseful Combination
# 13  building        building:levels       commercial     Useful Combination
# 14  building                   name       commercial     Useful Combination
# 15  building              mapillary       commercial     Useful Combination
# 16   amenity                website       restaurant     Useful Combination
# 17   amenity                  phone       restaurant  NonUseful Combination
# 18   amenity              mapillary       restaurant     Useful Combination
# 19   amenity                 source       restaurant     Useful Combination
# 20   amenity          addr:postcode       restaurant     Useful Combination
# 21   amenity               building       restaurant  NonUseful Combination
# 22   amenity              mapillary        fast_food     Useful Combination
# 23   amenity               operator  bicycle_parking     Useful Combination
# 24   amenity              mapillary  bicycle_parking     Useful Combination
# 25   amenity                 access  bicycle_parking     Useful Combination
# 26   amenity                covered  bicycle_parking     Useful Combination
# 27   amenity        source:position  bicycle_parking     Useful Combination
# 28   amenity            survey:date  bicycle_parking     Useful Combination
# 29   amenity                 source          parking     Useful Combination
# 30   amenity                 access          parking     Useful Combination
# 31   amenity                surface          parking     Useful Combination
# 32   amenity              mapillary            bench     Useful Combination
# 33   amenity        source:position            bench     Useful Combination
# 34   amenity            survey:date            bench     Useful Combination
# 35   highway             lamp_mount      street_lamp   Required Combination
# 36   highway               material      street_lamp  NonUseful Combination
# 37   highway                 height      street_lamp  NonUseful Combination
# 38   highway                surface          service     Useful Combination
# 39   highway         winter_service          footway     Useful Combination
# 40   highway                footway          footway   Required Combination
# 41   highway  traffic_signals:sound         crossing     Useful Combination
# 42   highway                bicycle         crossing     Useful Combination
# 43   highway                 source      street_lamp     Useful Combination
# 44   highway               lamp_ref      street_lamp     Useful Combination
# 45   highway               material      street_lamp  NonUseful Combination
# 46   highway             lamp_mount      street_lamp   Required Combination
# 47   highway                 height      street_lamp  NonUseful Combination
# 48   highway                 source          footway     Useful Combination
# 49   highway                surface          footway     Useful Combination
# 50   highway                  width          footway     Useful Combination
# 51   highway                footway          footway   Required Combination

# %%
buiOtawa2 = pd.read_csv('buildingOtawa2.csv', delimiter=";", encoding='latin-1')
buiOtawa2 = buiOtawa2.iloc[:,1:]
ameOtawa2 = pd.read_csv('amenityOtawa2.csv', delimiter=";", encoding='latin-1')
ameOtawa2 = ameOtawa2.iloc[:,1:]
# touOtawa = pd.read_csv('tourismOtawa.csv', delimiter=";", encoding='latin-1')
# touOtawa = touOtawa.iloc[:,1:]
higOtawa2 = pd.read_csv('highwayOtawa2.csv', delimiter=";", encoding='latin-1')
higOtawa2 = higOtawa2.iloc[:,1:]
Otawa2 = buiOtawa2.append(ameOtawa2, ignore_index=True)
# Otawa = Otawa.append(touOtawa, ignore_index = True)
Otawa2 = Otawa2.append(higOtawa2, ignore_index = True)
Otawa2
# Out:
#        alpha                 alphap             beta                   Role
# 0   building                   name       apartments     Useful Combination
# 1   building               operator       apartments  NonUseful Combination
# 2   building          addr:postcode       apartments     Useful Combination
# 3   building       addr:housenumber              yes     Useful Combination
# 4   building            addr:street              yes     Useful Combination
# 5   building        building:levels              yes     Useful Combination
# 6   building                   name              yes     Useful Combination
# 7   building                 office              yes  NonUseful Combination
# 8   building                amenity              yes  NonUseful Combination
# 9   building        building:levels       commercial     Useful Combination
# 10  building                   name       commercial     Useful Combination
# 11   amenity                website       restaurant     Useful Combination
# 12   amenity                  phone       restaurant  NonUseful Combination
# 13   amenity                 source       restaurant     Useful Combination
# 14   amenity          addr:postcode       restaurant     Useful Combination
# 15   amenity               building       restaurant  NonUseful Combination
# 16   amenity               operator  bicycle_parking     Useful Combination
# 17   amenity              mapillary  bicycle_parking     Useful Combination
# 18   amenity                 access  bicycle_parking     Useful Combination
# 19   amenity                covered  bicycle_parking     Useful Combination
# 20   amenity        source:position  bicycle_parking     Useful Combination
# 21   amenity                 source          parking     Useful Combination
# 22   amenity                 access          parking     Useful Combination
# 23   amenity                surface          parking     Useful Combination
# 24   amenity              mapillary            bench     Useful Combination
# 25   highway             lamp_mount      street_lamp     Useful Combination
# 26   highway               material      street_lamp  NonUseful Combination
# 27   highway                 height      street_lamp  NonUseful Combination
# 28   highway                surface          service     Useful Combination
# 29   highway         winter_service          footway     Useful Combination
# 30   highway                footway          footway   Required Combination
# 31   highway  traffic_signals:sound         crossing     Useful Combination
# 32   highway                bicycle         crossing     Useful Combination
# 33   highway                 source      street_lamp     Useful Combination
# 34   highway               lamp_ref      street_lamp     Useful Combination
# 35   highway               material      street_lamp  NonUseful Combination
# 36   highway             lamp_mount      street_lamp     Useful Combination
# 37   highway                 height      street_lamp  NonUseful Combination
# 38   highway                 source          footway     Useful Combination
# 39   highway                surface          footway     Useful Combination
# 40   highway                  width          footway     Useful Combination
# 41   highway                footway          footway   Required Combination

# %%
buiOtawa3 = pd.read_csv('buildingOtawa3.csv', delimiter=";", encoding='latin-1')
buiOtawa3 = buiOtawa3.iloc[:,1:]
ameOtawa3 = pd.read_csv('amenityOtawa3.csv', delimiter=";", encoding='latin-1')
ameOtawa3 = ameOtawa3.iloc[:,1:]
# touOtawa = pd.read_csv('tourismOtawa.csv', delimiter=";", encoding='latin-1')
# touOtawa = touOtawa.iloc[:,1:]
higOtawa3 = pd.read_csv('highwayOtawa3.csv', delimiter=";", encoding='latin-1')
higOtawa3 = higOtawa3.iloc[:,1:]
Otawa3 = buiOtawa3.append(ameOtawa3, ignore_index=True)
# Otawa = Otawa.append(touOtawa, ignore_index = True)
Otawa3 = Otawa3.append(higOtawa3, ignore_index = True)
Otawa3
# Out:
#         alpha         alphap        beta                   Role
# 0    building           name  apartments     Useful Combination
# 1    building       operator  apartments  NonUseful Combination
# 2    building      mapillary  apartments     Useful Combination
# 3    building  addr:postcode  apartments     Useful Combination
# 4    building    survey:date  apartments     Useful Combination
# ..        ...            ...         ...                    ...
# 111   highway            lit     footway     Useful Combination
# 112   highway        surface     footway     Useful Combination
# 113   highway          layer     footway  NonUseful Combination
# 114   highway        name:es     footway     Useful Combination
# 115   highway        footway     footway   Required Combination
#
# [116 rows x 4 columns]

# %%
buiSantiagoChile = pd.read_csv('buildingSantiagoChile.csv', delimiter=";", encoding='latin-1')
buiSantiagoChile = buiSantiagoChile.iloc[:,1:]
ameSantiagoChile = pd.read_csv('amenitySantiagoChile.csv', delimiter=";", encoding='latin-1')
ameSantiagoChile = ameSantiagoChile.iloc[:,1:]
touSantiagoChile = pd.read_csv('tourismSantiagoChile.csv', delimiter=";", encoding='latin-1')
touSantiagoChile = touSantiagoChile.iloc[:,1:]
higSantiagoChile = pd.read_csv('highwaySantiagoChile.csv', delimiter=";", encoding='latin-1')
higSantiagoChile = higSantiagoChile.iloc[:,1:]
SantiagoChile = buiSantiagoChile.append(ameSantiagoChile, ignore_index=True)
SantiagoChile = SantiagoChile.append(touSantiagoChile, ignore_index = True)
SantiagoChile = SantiagoChile.append(higSantiagoChile, ignore_index = True)
SantiagoChile
# Out:
#        alpha           alphap     beta                   Role
# 0   building            layer      yes  NonUseful Combination
# 1   building  building:levels      yes     Useful Combination
# 2   building        addr:city      yes     Useful Combination
# 3   building      addr:street      yes     Useful Combination
# 4   building             name      yes     Useful Combination
# ..       ...              ...      ...                    ...
# 63   highway            layer  footway  NonUseful Combination
# 64   highway           tunnel  footway     Useful Combination
# 65   highway            horse  footway     Useful Combination
# 66   highway          footway  footway   Required Combination
# 67   highway           access  service     Useful Combination
#
# [68 rows x 4 columns]

# %%
buiRome = pd.read_csv('buildingRome.csv', delimiter=";", encoding='latin-1')
buiRome = buiRome.iloc[:,1:]
ameRome = pd.read_csv('amenityRome.csv', delimiter=";", encoding='latin-1')
ameRome = ameRome.iloc[:,1:]
touRome = pd.read_csv('tourismRome.csv', delimiter=";", encoding='latin-1')
touRome = touRome.iloc[:,1:]
higRome = pd.read_csv('highwayRome.csv', delimiter=";", encoding='latin-1')
higRome = higRome.iloc[:,1:]
Rome = buiRome.append(ameRome, ignore_index=True)
Rome = Rome.append(touRome, ignore_index = True)
Rome = Rome.append(higRome, ignore_index = True)
Rome
# Out:
#         alpha            alphap     beta                   Role
# 0    building            source   church     Useful Combination
# 1    building       addr:street      yes     Useful Combination
# 2    building              name      yes     Useful Combination
# 3    building           tourism      yes  NonUseful Combination
# 4    building  addr:housenumber      yes     Useful Combination
# ..        ...               ...      ...                    ...
# 251   highway           footway  footway   Required Combination
# 252   highway           covered  footway     Useful Combination
# 253   highway            source    steps     Useful Combination
# 254   highway            access    steps     Useful Combination
# 255   highway              note    steps     Useful Combination
#
# [256 rows x 4 columns]

# %%
buiWuhan = pd.read_csv('buildingWuhan.csv', delimiter=";", encoding='latin-1')
buiWuhan = buiWuhan.iloc[:,1:]
ameWuhan = pd.read_csv('amenityWuhan.csv', delimiter=";", encoding='latin-1')
ameWuhan = ameWuhan.iloc[:,1:]
touWuhan = pd.read_csv('tourismWuhan.csv', delimiter=";", encoding='latin-1')
touWuhan = touWuhan.iloc[:,1:]
higWuhan = pd.read_csv('highwayWuhan.csv', delimiter=";", encoding='latin-1')
higWuhan = higWuhan.iloc[:,1:]
Wuhan = buiWuhan.append(ameWuhan, ignore_index=True)
Wuhan = Wuhan.append(touWuhan, ignore_index = True)
Wuhan = Wuhan.append(higWuhan, ignore_index = True)
Wuhan
# Out:
#        alpha            alphap             beta                   Role
# 0   building              name              yes     Useful Combination
# 1   building            height              yes     Useful Combination
# 2   building   building:levels              yes     Useful Combination
# 3   building              name       commercial     Useful Combination
# 4   building   building:levels       commercial     Useful Combination
# 5   building              name       apartments     Useful Combination
# 6   building              name      residential     Useful Combination
# 7   building            height      residential     Useful Combination
# 8   building   building:levels      residential     Useful Combination
# 9   building              name              yes     Useful Combination
# 10  building   building:levels              yes     Useful Combination
# 11  building            height              yes     Useful Combination
# 12   amenity               atm             bank     Useful Combination
# 13   tourism  addr:housenumber            hotel     Useful Combination
# 14   tourism       addr:street            hotel     Useful Combination
# 15   tourism           name:en            hotel     Useful Combination
# 16   tourism          building            hotel  NonUseful Combination
# 17   highway      construction     construction     Useful Combination
# 18   highway              name      residential     Useful Combination
# 19   highway            oneway      residential     Useful Combination
# 20   highway           surface      residential     Useful Combination
# 21   highway              name          primary     Useful Combination
# 22   highway             lanes          primary     Useful Combination
# 23   highway            source          primary     Useful Combination
# 24   highway           surface          primary     Useful Combination
# 25   highway             layer          primary  NonUseful Combination
# 26   highway              name         tertiary     Useful Combination
# 27   highway            oneway         tertiary     Useful Combination
# 28   highway              name        secondary     Useful Combination
# 29   highway             lanes        secondary     Useful Combination
# 30   highway               lit        secondary     Useful Combination
# 31   highway           surface        secondary     Useful Combination
# 32   highway             layer        secondary  NonUseful Combination
# 33   highway         motorroad            trunk     Useful Combination
# 34   highway            source            trunk     Useful Combination
# 35   highway            bridge            trunk     Useful Combination
# 36   highway             layer            trunk  NonUseful Combination
# 37   highway          maxspeed            trunk     Useful Combination
# 38   highway            bridge       trunk_link     Useful Combination
# 39   highway             layer       trunk_link  NonUseful Combination
# 40   highway            bridge          footway     Useful Combination
# 41   highway             layer          footway  NonUseful Combination
# 42   highway           footway          footway   Required Combination
# 43   highway            oneway          service     Useful Combination
# 44   highway   traffic_signals  traffic_signals   Required Combination
# 45   highway              name         tertiary     Useful Combination
# 46   highway            oneway         tertiary     Useful Combination
# 47   highway             lanes         tertiary     Useful Combination
# 48   highway              name          primary     Useful Combination
# 49   highway             lanes          primary     Useful Combination
# 50   highway             layer          primary  NonUseful Combination
# 51   highway              name      residential     Useful Combination
# 52   highway            oneway      residential     Useful Combination
# 53   highway            source      residential     Useful Combination
# 54   highway             layer          footway  NonUseful Combination
# 55   highway            bridge          footway     Useful Combination
# 56   highway           footway          footway   Required Combination
# 57   highway           bicycle             path     Useful Combination
# 58   highway              foot             path     Useful Combination
# 59   highway        segregated             path     Useful Combination

# %%
import pandas as pd
import numpy as np
import pickle
import joblib
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
ElCairo2.to_csv('ElCairo2.csv', index = False)

# %%
Barcelona
# Out:
#        alpha            alphap        beta                   Role
# 0   building  addr:housenumber         yes     Useful Combination
# 1   building       addr:street         yes     Useful Combination
# 2   building   building:levels  apartments     Useful Combination
# 3   building  addr:housenumber  apartments     Useful Combination
# 4   building     addr:postcode  apartments     Useful Combination
# ..       ...               ...         ...                    ...
# 58   highway               lit     footway     Useful Combination
# 59   highway           surface     footway     Useful Combination
# 60   highway             layer     footway  NonUseful Combination
# 61   highway           name:es     footway     Useful Combination
# 62   highway           footway     footway   Required Combination
#
# [63 rows x 4 columns]

# %% [markdown]
# ### We create the function.

# %%
def error(dataset, deli):
    data = pd.read_csv(dataset, delimiter = deli)
#     data = pd.read_csv('ElCairo2.csv', delimiter = ',', encoding='latin-1')
    index = data.iloc[:,0]
    obj = data['Role']
    data = data[['alpha','alphap','beta']]
    data1 = list(data['alphap'])
    data2 = list(data['beta'])
    file = open("dict_all.obj",'rb')
    dict_all_loaded = pickle.load(file)
    file = open("target.obj",'rb')
    dict_obj_loaded = pickle.load(file)
    file.close()
    file.close()
    for col in data.columns[0:3]:
            data.replace(dict_all_loaded[col], inplace=True)
    data['aux1']=data1 
    data['aux2']=data2
    DF = pd.read_csv('DF.csv')
    ee = []
    for i in range(len(DF)):
        ee.append(str(DF["alphap"][i]) + " " + str(DF["beta"][i]))
    DF['conc'] = ee
    def get_key(val):
        for key, value in dict_obj_loaded.items():
             if val == value:
                 return key
        return "key doesn't exist"
    rf = joblib.load("./random_forest.joblib")
    lista = []
    for i in range(len(data)):        
            if str(data['alphap'][i]) + " " + str(data['beta'][i]) not in DF['conc'].values:
                lista.append(np.array([dict_obj_loaded['Useful Combination']]))
            else:
                pred = pd.DataFrame(data.iloc[i,0:3]).T
                a = rf.predict(pred)
                lista.append(a)

    lista1=[]
    for i in lista: lista1.append(i[0])
    obj1 = [dict_obj_loaded[x] for x in obj]
    list2 = []
    for i in lista1:
        list2.append(get_key(i))
    df = {'ID': index, 'Error': list2, 'Error real': obj}
    df = pd.DataFrame(df)
    print(df)
    print(accuracy_score(lista1,obj1))
    print(f1_score(lista1,obj1, average = 'weighted'))
    print(confusion_matrix(obj1, lista1))

# %% [markdown]
# ### We check the quality of the results in Wuhan example.

# %%
Wuhan.to_csv('Wuhan.csv', index = False)  
error('Wuhan.csv', deli = ',')
# Out:
#           ID                  Error             Error real
# 0   building     Useful Combination     Useful Combination
# 1   building     Useful Combination     Useful Combination
# 2   building     Useful Combination     Useful Combination
# 3   building     Useful Combination     Useful Combination
# 4   building     Useful Combination     Useful Combination
# 5   building     Useful Combination     Useful Combination
# 6   building     Useful Combination     Useful Combination
# 7   building     Useful Combination     Useful Combination
# 8   building     Useful Combination     Useful Combination
# 9   building     Useful Combination     Useful Combination
# 10  building     Useful Combination     Useful Combination
# 11  building     Useful Combination     Useful Combination
# 12   amenity     Useful Combination     Useful Combination
# 13   tourism     Useful Combination     Useful Combination
# 14   tourism     Useful Combination     Useful Combination
# 15   tourism     Useful Combination     Useful Combination
# 16   tourism  NonUseful Combination  NonUseful Combination
# 17   highway     Useful Combination     Useful Combination
# 18   highway     Useful Combination     Useful Combination
# 19   highway     Useful Combination     Useful Combination
# 20   highway     Useful Combination     Useful Combination
# 21   highway     Useful Combination     Useful Combination
# 22   highway     Useful Combination     Useful Combination
# 23   highway     Useful Combination     Useful Combination
# 24   highway     Useful Combination     Useful Combination
# 25   highway     Useful Combination  NonUseful Combination
# 26   highway     Useful Combination     Useful Combination
# 27   highway     Useful Combination     Useful Combination
# 28   highway     Useful Combination     Useful Combination
# 29   highway     Useful Combination     Useful Combination
# 30   highway     Useful Combination     Useful Combination
# 31   highway     Useful Combination     Useful Combination
# 32   highway     Useful Combination  NonUseful Combination
# 33   highway     Useful Combination     Useful Combination
# 34   highway     Useful Combination     Useful Combination
# 35   highway     Useful Combination     Useful Combination
# 36   highway     Useful Combination  NonUseful Combination
# 37   highway     Useful Combination     Useful Combination
# 38   highway     Useful Combination     Useful Combination
# 39   highway     Useful Combination  NonUseful Combination
# 40   highway     Useful Combination     Useful Combination
# 41   highway  NonUseful Combination  NonUseful Combination
# 42   highway   Required Combination   Required Combination
# 43   highway     Useful Combination     Useful Combination
# 44   highway   Required Combination   Required Combination
# 45   highway     Useful Combination     Useful Combination
# 46   highway     Useful Combination     Useful Combination
# 47   highway     Useful Combination     Useful Combination
# 48   highway     Useful Combination     Useful Combination
# 49   highway     Useful Combination     Useful Combination
# 50   highway     Useful Combination  NonUseful Combination
# 51   highway     Useful Combination     Useful Combination
# 52   highway     Useful Combination     Useful Combination
# 53   highway     Useful Combination     Useful Combination
# 54   highway  NonUseful Combination  NonUseful Combination
# 55   highway     Useful Combination     Useful Combination
# 56   highway   Required Combination   Required Combination
# 57   highway     Useful Combination     Useful Combination
# 58   highway     Useful Combination     Useful Combination
# 59   highway     Useful Combination     Useful Combination
# 0.9166666666666666
# 0.9335834068843778
# [[ 3  0  5]
#  [ 0  3  0]
#  [ 0  0 49]]
