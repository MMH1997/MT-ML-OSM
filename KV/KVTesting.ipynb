# %% [markdown]
# ### We import the libraries.

# %%
import pandas as pd
import numpy as np
import pickle
import joblib
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### We load datasets of the tags.

# %%
buiBarcelona = pd.read_csv('buildingBarcelona.csv', delimiter=";", encoding='latin-1')
buiBarcelona = buiBarcelona.iloc[:,1:]
ameBarcelona = pd.read_csv('amenityBarcelona.csv', delimiter=";", encoding='latin-1')
ameBarcelona = ameBarcelona.iloc[:,1:]
touBarcelona = pd.read_csv('tourismBarcelona.csv', delimiter=";", encoding='latin-1')
touBarcelona = touBarcelona.iloc[:,1:]
higBarcelona = pd.read_csv('highwayBarcelona.csv', delimiter=";", encoding='latin-1')
higBarcelona = higBarcelona.iloc[:,1:]
Barcelona = buiBarcelona.append(ameBarcelona, ignore_index=True)
Barcelona = Barcelona.append(touBarcelona, ignore_index = True)
Barcelona = Barcelona.append(higBarcelona, ignore_index = True)
Barcelona
# Out:
#          alpha          conflict      beta error   addrcity addrcountry  \
# 0     building  amenity building    school   yes  Barcelona          ES
# 1     building  amenity building    school   yes  Barcelona          ES
# 2     building  amenity building    school   yes        NaN         NaN
# 3     building  amenity building    school   yes        NaN         NaN
# 4     building  amenity building    school   yes        NaN         NaN
# ...        ...               ...       ...   ...        ...         ...
# 1318   highway           highway     steps    no        NaN         NaN
# 1319   highway           highway     steps    no        NaN         NaN
# 1320   highway           highway     steps    no        NaN         NaN
# 1321   highway    highway indoor  corridor   yes        NaN         NaN
# 1322   highway    highway indoor  corridor   yes        NaN         NaN
#
#          addrhousename addrhousenumber  addrpostcode               addrstreet  \
# 0     Escola La Sedeta             321        8025.0       Carrer de SicÃ­lia
# 1            La Sedeta           67-73        8025.0  Carrer de la IndÃºstria
# 2                  NaN             NaN           NaN                      NaN
# 3                  NaN             NaN           NaN                      NaN
# 4                  NaN             NaN           NaN                      NaN
# ...                ...             ...           ...                      ...
# 1318               NaN             NaN           NaN                      NaN
# 1319               NaN             NaN           NaN                      NaN
# 1320               NaN             NaN           NaN                      NaN
# 1321               NaN             NaN           NaN                      NaN
# 1322               NaN             NaN           NaN                      NaN
#
#       ... maxspeedtype short_name onewaybicycle  motor_vehicle lanesbackward  \
# 0     ...          NaN        NaN           NaN            NaN           NaN
# 1     ...          NaN        NaN           NaN            NaN           NaN
# 2     ...          NaN        NaN           NaN            NaN           NaN
# 3     ...          NaN        NaN           NaN            NaN           NaN
# 4     ...          NaN        NaN           NaN            NaN           NaN
# ...   ...          ...        ...           ...            ...           ...
# 1318  ...          NaN        NaN           NaN            NaN           NaN
# 1319  ...          NaN        NaN           NaN            NaN           NaN
# 1320  ...          NaN        NaN           NaN            NaN           NaN
# 1321  ...          NaN        NaN           NaN            NaN           NaN
# 1322  ...          NaN        NaN           NaN            NaN           NaN
#
#      lanesforward  handrail  incline    indoor level
# 0             NaN       NaN      NaN       NaN   NaN
# 1             NaN       NaN      NaN       NaN   NaN
# 2             NaN       NaN      NaN       NaN   NaN
# 3             NaN       NaN      NaN       NaN   NaN
# 4             NaN       NaN      NaN       NaN   NaN
# ...           ...       ...      ...       ...   ...
# 1318          NaN       NaN       up       NaN   NaN
# 1319          NaN       NaN      NaN       NaN   NaN
# 1320          NaN       NaN      NaN       NaN   NaN
# 1321          NaN       NaN      NaN  corridor  -1.0
# 1322          NaN       NaN      NaN  corridor  -1.0
#
# [1323 rows x 125 columns]

# %%
buiBoston = pd.read_csv('buildingBoston.csv', delimiter=";", encoding='latin-1')
buiBoston = buiBoston.iloc[:,1:]
ameBoston = pd.read_csv('amenityBoston.csv', delimiter=";", encoding='latin-1')
ameBoston = ameBoston.iloc[:,1:]
touBoston = pd.read_csv('tourismBoston.csv', delimiter=";", encoding='latin-1')
touBoston = touBoston.iloc[:,1:]
higBoston = pd.read_csv('highwayBoston.csv', delimiter=";", encoding='latin-1')
higBoston = higBoston.iloc[:,1:]
Boston = buiBoston.append(ameBoston, ignore_index=True)
Boston = Boston.append(touBoston, ignore_index = True)
Boston = Boston.append(higBoston, ignore_index = True)
Boston
# Out:
#          alpha                     conflict        beta error    building  \
# 0     building  amenity healthcare building    hospital   yes    hospital
# 1     building  amenity healthcare building    hospital   yes    hospital
# 2     building  amenity healthcare building    hospital   yes    hospital
# 3     building             building amenity  university   yes  university
# 4     building             building amenity  university   yes  university
# ...        ...                          ...         ...   ...         ...
# 1083   highway                      highway     primary    no         NaN
# 1084   highway                      highway     primary    no         NaN
# 1085   highway                      highway     primary    no         NaN
# 1086   highway                      highway     primary    no         NaN
# 1087   highway                      highway     primary    no         NaN
#
#                       name  buildinglevels  layer addrhousenumber  \
# 0     Emergency Department             NaN    NaN             NaN
# 1                      NaN             9.0    1.0             NaN
# 2          Proger Building             9.0    1.0         704;780
# 3                  Stearns             NaN    NaN             NaN
# 4                   Arnold             NaN    NaN             NaN
# ...                    ...             ...    ...             ...
# 1083      Cambridge Street             NaN    NaN             NaN
# 1084      Cambridge Street             NaN    NaN             NaN
# 1085      Cambridge Street             NaN    NaN             NaN
# 1086       Congress Street             NaN    NaN             NaN
# 1087      Cambridge Street             NaN    NaN             NaN
#
#              addrstreet  ... horse  button_operated traffic_signalssound  \
# 0                   NaN  ...   NaN              NaN                  NaN
# 1                   NaN  ...   NaN              NaN                  NaN
# 2     Washington Street  ...   NaN              NaN                  NaN
# 3                   NaN  ...   NaN              NaN                  NaN
# 4                   NaN  ...   NaN              NaN                  NaN
# ...                 ...  ...   ...              ...                  ...
# 1083                NaN  ...   NaN              NaN                  NaN
# 1084                NaN  ...   NaN              NaN                  NaN
# 1085                NaN  ...   NaN              NaN                  NaN
# 1086                NaN  ...   NaN              NaN                  NaN
# 1087                NaN  ...   NaN              NaN                  NaN
#
#      traffic_signalsvibration kerb mapillary surveydate door entrance  \
# 0                         NaN  NaN       NaN        NaN  NaN      NaN
# 1                         NaN  NaN       NaN        NaN  NaN      NaN
# 2                         NaN  NaN       NaN        NaN  NaN      NaN
# 3                         NaN  NaN       NaN        NaN  NaN      NaN
# 4                         NaN  NaN       NaN        NaN  NaN      NaN
# ...                       ...  ...       ...        ...  ...      ...
# 1083                      NaN  NaN       NaN        NaN  NaN      NaN
# 1084                      NaN  NaN       NaN        NaN  NaN      NaN
# 1085                      NaN  NaN       NaN        NaN  NaN      NaN
# 1086                      NaN  NaN       NaN        NaN  NaN      NaN
# 1087                      NaN  NaN       NaN        NaN  NaN      NaN
#
#      cyclewaybothlane
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1083              NaN
# 1084              NaN
# 1085              NaN
# 1086        pictogram
# 1087              NaN
#
# [1088 rows x 174 columns]

# %%
buiBrussel = pd.read_csv('buildingBrussel.csv', delimiter=";", encoding='latin-1')
buiBrussel = buiBrussel.iloc[:,1:]
ameBrussel = pd.read_csv('amenityBrussel.csv', delimiter=";", encoding='latin-1')
ameBrussel = ameBrussel.iloc[:,1:]
touBrussel = pd.read_csv('tourismBrussel.csv', delimiter=";", encoding='latin-1')
touBrussel = touBrussel.iloc[:,1:]
higBrussel = pd.read_csv('highwayBrussel.csv', delimiter=";", encoding='latin-1')
higBrussel = higBrussel.iloc[:,1:]
Brussel = buiBrussel.append(ameBrussel, ignore_index=True)
Brussel = Brussel.append(touBrussel, ignore_index = True)
Brussel = Brussel.append(higBrussel, ignore_index = True)
Brussel = Brussel.drop(Brussel[(Brussel['error'] != 'no') & (Brussel['error'] != 'yes')].index)
Brussel
# Out:
#         alpha                              conflict         beta error  \
# 0    building  toilets:access surveillance building       public   yes
# 1    building  toilets:access surveillance building       public   yes
# 2    building                      building landuse   commercial   yes
# 3    building                      building landuse   commercial   yes
# 4    building                                   NaN       office   yes
# ..        ...                                   ...          ...   ...
# 591   highway      proposed:highway highway landuse  residential    no
# 592   highway      proposed:highway highway landuse  residential    no
# 593   highway      proposed:highway highway landuse  residential    no
# 594   highway      proposed:highway highway landuse  residential    no
# 595   highway              public_transport railway     platform    no
#
#                 addrcity  addrpostcode                            addrstreet  \
# 0    Bruxelles - Brussel        1000.0       Place de la Bourse - Beursplein
# 1    Bruxelles - Brussel        1000.0  Place Saint-GÃ©ry - Sint-Goriksplein
# 2                    NaN           NaN                                   NaN
# 3    Bruxelles - Brussel        1000.0  Rue des Chartreux - Kartuizersstraat
# 4                    NaN           NaN                                   NaN
# ..                   ...           ...                                   ...
# 591                  NaN           NaN                                   NaN
# 592                  NaN           NaN                                   NaN
# 593                  NaN           NaN                                   NaN
# 594                  NaN           NaN                                   NaN
# 595                  NaN           NaN                                   NaN
#
#        building  buildinglevels  \
# 0        public             2.0
# 1        public             NaN
# 2    commercial             9.0
# 3    commercial             NaN
# 4        office             NaN
# ..          ...             ...
# 591         NaN             NaN
# 592         NaN             NaN
# 593         NaN             NaN
# 594         NaN             NaN
# 595         NaN             NaN
#
#                                                  image  ... footway noname  \
# 0    https://images.mapillary.com/G8HzHBp7dHJCapdMl...  ...     NaN    NaN
# 1                                                  NaN  ...     NaN    NaN
# 2                                                  NaN  ...     NaN    NaN
# 3                                                  NaN  ...     NaN    NaN
# 4                                                  NaN  ...     NaN    NaN
# ..                                                 ...  ...     ...    ...
# 591                                                NaN  ...     NaN    NaN
# 592                                                NaN  ...     NaN    NaN
# 593                                                NaN  ...     NaN    NaN
# 594                                                NaN  ...     NaN    NaN
# 595                                                NaN  ...     NaN    NaN
#
#      bus public_transport emergency horse motor_vehicle taxi      vehicle  \
# 0    NaN              NaN       NaN   NaN           NaN  NaN          NaN
# 1    NaN              NaN       NaN   NaN           NaN  NaN          NaN
# 2    NaN              NaN       NaN   NaN           NaN  NaN          NaN
# 3    NaN              NaN       NaN   NaN           NaN  NaN          NaN
# 4    NaN              NaN       NaN   NaN           NaN  NaN          NaN
# ..   ...              ...       ...   ...           ...  ...          ...
# 591  yes              NaN       yes   yes           NaN  yes  destination
# 592  yes              NaN       yes   yes           NaN  yes  destination
# 593  yes              NaN       yes   yes           NaN  yes  destination
# 594  yes              NaN       yes   NaN           NaN  NaN          NaN
# 595  yes         platform       NaN   NaN           NaN  NaN          NaN
#
#     route_ref
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 591       NaN
# 592       NaN
# 593       NaN
# 594       NaN
# 595       NaN
#
# [596 rows x 174 columns]

# %%
# buiElCairo = pd.read_csv('buildingElCairo.csv', delimiter=";", encoding='latin-1')
# buiElCairo = buiElCairo.iloc[:,1:]
ameElCairo = pd.read_csv('amenityElCairo.csv', delimiter=";", encoding='latin-1')
ameElCairo = ameElCairo.iloc[:,1:]
# touElCairo = pd.read_csv('tourismElCairo.csv', delimiter=";", encoding='latin-1')
# touElCairo = touElCairo.iloc[:,1:]
higElCairo = pd.read_csv('highwayElCairo.csv', delimiter=";", encoding='latin-1')
higElCairo = higElCairo.iloc[:,1:]
ElCairo = ameElCairo.append(higElCairo, ignore_index = True)
ElCairo
# Out:
#         alpha            conflict         beta error  historic  \
# 0     amenity  amenity healthcare     pharmacy   yes       NaN
# 1     amenity  amenity healthcare     pharmacy   yes       NaN
# 2     amenity  amenity healthcare     pharmacy   yes       NaN
# 3     amenity  amenity healthcare     pharmacy   yes       NaN
# 4     amenity  amenity healthcare     hospital    no       NaN
# ...       ...                 ...          ...   ...       ...
# 1661  highway     highway landuse  residential    no       NaN
# 1662  highway     highway landuse  residential    no       NaN
# 1663  highway     highway landuse  residential    no       NaN
# 1664  highway     highway landuse  residential    no       NaN
# 1665  highway     highway landuse  residential    no       NaN
#
#                                                   name  \
# 0                                             Al Azaby
# 1                                                  NaN
# 2                                               ÙØ¶Ù
# 3             ØµÙØ¯ÙÙØ© Ø§ÙØ§Ø³Ø¹Ø§Ù Ø¨Ø±Ù
# Ø³ÙØ³
# 4     Ù
# Ø³Ø´ØªÙÙ Ø§ÙØ¬Ù
# ÙÙØ±ÙØ© Ø§ÙØªØ¹ÙÙÙ
# Ù
# ...                                                ...
# 1661                                               NaN
# 1662                                               NaN
# 1663                                               NaN
# 1664                                               NaN
# 1665                                  ???? ?????? ????
#
#                                                 namear  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                               ÙØ¶Ù
# 3             ØµÙØ¯ÙÙØ© Ø§ÙØ§Ø³Ø¹Ø§Ù Ø¨Ø±Ù
# Ø³ÙØ³
# 4     Ù
# Ø³Ø´ØªÙÙ Ø§ÙØ¬Ù
# ÙÙØ±ÙØ© Ø§ÙØªØ¹ÙÙÙ
# Ù
# ...                                                ...
# 1661                                               NaN
# 1662                                               NaN
# 1663                                               NaN
# 1664                                               NaN
# 1665                                  ???? ?????? ????
#
#                              nameen  barrier  place  ... noteen covered  \
# 0                               NaN      NaN    NaN  ...    NaN     NaN
# 1                               NaN      NaN    NaN  ...    NaN     NaN
# 2                               NaN      NaN    NaN  ...    NaN     NaN
# 3          El Esaaf Pharmacy-Ramsis      NaN    NaN  ...    NaN     NaN
# 4     El-Gomhoria Teaching Hospital      NaN    NaN  ...    NaN     NaN
# ...                             ...      ...    ...  ...    ...     ...
# 1661                            NaN      NaN    NaN  ...    NaN     NaN
# 1662                            NaN      NaN    NaN  ...    NaN     NaN
# 1663                            NaN      NaN    NaN  ...    NaN     NaN
# 1664                            NaN      NaN    NaN  ...    NaN     NaN
# 1665            Zuqaq Al Amir Abbas      NaN    NaN  ...    NaN     NaN
#
#       alt_namear healthcare  \
# 0            NaN   pharmacy
# 1            NaN   pharmacy
# 2            NaN   pharmacy
# 3            NaN        NaN
# 4            NaN   hospital
# ...          ...        ...
# 1661         NaN        NaN
# 1662         NaN        NaN
# 1663         NaN        NaN
# 1664         NaN        NaN
# 1665         NaN        NaN
#
#                                         contactfacebook  emergency  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3     https://www.facebook.com/ØµÙØ¯ÙÙØ©-Ø§ÙØ§Ø³...        NaN
# 4                                                   NaN        yes
# ...                                                 ...        ...
# 1661                                                NaN        NaN
# 1662                                                NaN        NaN
# 1663                                                NaN        NaN
# 1664                                                NaN        NaN
# 1665                                                NaN        NaN
#
#       healthcarespeciality  operatortype roofshape motor_vehicle
# 0                      NaN           NaN       NaN           NaN
# 1                      NaN           NaN       NaN           NaN
# 2                      NaN           NaN       NaN           NaN
# 3                      NaN           NaN       NaN           NaN
# 4                  general    government       NaN           NaN
# ...                    ...           ...       ...           ...
# 1661                   NaN           NaN       NaN           NaN
# 1662                   NaN           NaN       NaN           NaN
# 1663                   NaN           NaN       NaN           NaN
# 1664                   NaN           NaN       NaN           NaN
# 1665                   NaN           NaN       NaN           NaN
#
# [1666 rows x 78 columns]

# %%
buiLaHabana = pd.read_csv('buildingLaHabana.csv', delimiter=";", encoding='latin-1')
buiLaHabana = buiLaHabana.iloc[:,1:]
ameLaHabana = pd.read_csv('amenityLaHabana.csv', delimiter=";", encoding='latin-1')
ameLaHabana = ameLaHabana.iloc[:,1:]
touLaHabana = pd.read_csv('tourismLaHabana.csv', delimiter=";", encoding='latin-1')
touLaHabana = touLaHabana.iloc[:,1:]
higLaHabana = pd.read_csv('highwayLaHabana.csv', delimiter=";", encoding='latin-1')
higLaHabana = higLaHabana.iloc[:,1:]
LaHabana = buiLaHabana.append(ameLaHabana, ignore_index=True)
LaHabana = LaHabana.append(touLaHabana, ignore_index = True)
LaHabana = LaHabana.append(higLaHabana, ignore_index = True)
LaHabana = LaHabana.drop(LaHabana[(LaHabana['error'] != 'no') & (LaHabana['error'] != 'yes')].index)
LaHabana
# Out:
#         alpha          conflict         beta error addrhousenumber  building  \
# 0    building               NaN       office   yes               2    office
# 1    building  amenity building     hospital   yes             NaN  hospital
# 2    building  amenity building     hospital   yes             NaN  hospital
# 3    building          building       public   yes             NaN    public
# 4    building          building       public   yes             NaN    public
# ..        ...               ...          ...   ...             ...       ...
# 449   highway   highway landuse  residential    no             NaN       NaN
# 450   highway   highway landuse  residential    no             NaN       NaN
# 451   highway   highway landuse  residential    no             NaN       NaN
# 452   highway   highway landuse  residential    no             NaN       NaN
# 453   highway   highway landuse  residential    no             NaN       NaN
#
#      buildinglevels government  \
# 0               9.0   ministry
# 1               NaN        NaN
# 2               1.0        NaN
# 3               5.0   ministry
# 4               NaN   ministry
# ..              ...        ...
# 449             NaN        NaN
# 450             NaN        NaN
# 451             NaN        NaN
# 452             NaN        NaN
# 453             NaN        NaN
#
#                                                   name  \
# 0    Ministerio de la InformÃ¡tica y las Comunicaci...
# 1                   Hospital PedriÃ¡tico Centro Habana
# 2          Cuerpo de Guardia - Hospital La Dependiente
# 3             Ministerio de EconomÃ­a y PlanificaciÃ³n
# 4             Ministerio de EconomÃ­a y PlanificaciÃ³n
# ..                                                 ...
# 449                                           ObrapÃ­a
# 450                                         Inquisidor
# 451                                            Bernaza
# 452                                            Bernaza
# 453                              Brasil (Teniente Rey)
#
#                                             namede  ... tunnel crossing  \
# 0    Ministerium fÃ¼r Informatik und Kommunikation  ...    NaN      NaN
# 1                                              NaN  ...    NaN      NaN
# 2                                              NaN  ...    NaN      NaN
# 3                                              NaN  ...    NaN      NaN
# 4                                              NaN  ...    NaN      NaN
# ..                                             ...  ...    ...      ...
# 449                                            NaN  ...    NaN      NaN
# 450                                            NaN  ...    NaN      NaN
# 451                                            NaN  ...    NaN      NaN
# 452                                            NaN  ...    NaN      NaN
# 453                                            NaN  ...    NaN      NaN
#
#     crossingisland mapillary surveydate button_operated traffic_signalssound  \
# 0              NaN       NaN        NaN             NaN                  NaN
# 1              NaN       NaN        NaN             NaN                  NaN
# 2              NaN       NaN        NaN             NaN                  NaN
# 3              NaN       NaN        NaN             NaN                  NaN
# 4              NaN       NaN        NaN             NaN                  NaN
# ..             ...       ...        ...             ...                  ...
# 449            NaN       NaN        NaN             NaN                  NaN
# 450            NaN       NaN        NaN             NaN                  NaN
# 451            NaN       NaN        NaN             NaN                  NaN
# 452            NaN       NaN        NaN             NaN                  NaN
# 453            NaN       NaN        NaN             NaN                  NaN
#
#     traffic_signalsvibration motor_vehicle layer
# 0                        NaN           NaN   NaN
# 1                        NaN           NaN   NaN
# 2                        NaN           NaN   NaN
# 3                        NaN           NaN   NaN
# 4                        NaN           NaN   NaN
# ..                       ...           ...   ...
# 449                      NaN           NaN   NaN
# 450                      NaN           NaN   NaN
# 451                      NaN      delivery   NaN
# 452                      NaN      delivery   NaN
# 453                      NaN           NaN   NaN
#
# [452 rows x 85 columns]

# %%
buiLuanda = pd.read_csv('buildingLuanda.csv', delimiter=";", encoding='latin-1')
buiLuanda = buiLuanda.iloc[:,1:]
ameLuanda = pd.read_csv('amenityLuanda.csv', delimiter=";", encoding='latin-1')
ameLuanda = ameLuanda.iloc[:,1:]
# touLuanda = pd.read_csv('tourismLuanda.csv', delimiter=";", encoding='latin-1')
# touLuanda = touLuanda.iloc[:,1:]
higLuanda = pd.read_csv('highwayLuanda.csv', delimiter=";", encoding='latin-1')
higLuanda = higLuanda.iloc[:,1:]
Luanda = buiLuanda.append(ameLuanda, ignore_index=True)
# Luanda = Luanda.append(touLuanda, ignore_index = True)
Luanda = Luanda.append(higLuanda, ignore_index = True)
Luanda = Luanda.drop(Luanda[(Luanda['error'] != 'no') & (Luanda['error'] != 'yes')].index)
Luanda
# Out:
#          alpha          conflict         beta error    building  \
# 0     building          building   commercial   yes  commercial
# 1     building          building   commercial   yes  commercial
# 2     building          building   commercial   yes  commercial
# 3     building          building   commercial   yes  commercial
# 4     building          building   commercial   yes  commercial
# ...        ...               ...          ...   ...         ...
# 1413   highway  highway building  residential    no         NaN
# 1414   highway  highway building  residential    no         NaN
# 1415   highway  highway building  residential    no         NaN
# 1416   highway  highway building  residential    no         NaN
# 1417   highway  highway building  residential    no         NaN
#
#                              name                         website addrcity  \
# 0     ETOLA - Energia TÃ©cnica SA  http://www.energiatecnica.com/      NaN
# 1                  EdifÃ­cio KN10                             NaN   Luanda
# 2                Banco EconÃ³mico  https://www.bancoeconomico.ao/   Luanda
# 3                  Torres Dipanda                             NaN      NaN
# 4                       Audiconta                             NaN   Luanda
# ...                           ...                             ...      ...
# 1413                Rua de Ambaca                             NaN      NaN
# 1414       Rua de Santos Drummont                             NaN      NaN
# 1415                          NaN                             NaN      NaN
# 1416                          NaN                             NaN      NaN
# 1417                          NaN                             NaN      NaN
#
#                                              addrstreet addrhousenumber  ...  \
# 0                                                   NaN             NaN  ...
# 1                                  Rua Guilherme Capelo             NaN  ...
# 2     Avenida do 1Âº Congresso do MPLA (ex Avenida A...               8  ...
# 3                                                   NaN             NaN  ...
# 4                                          Rua de Timor              45  ...
# ...                                                 ...             ...  ...
# 1413                                                NaN             NaN  ...
# 1414                                                NaN             NaN  ...
# 1415                                                NaN             NaN  ...
# 1416                                                NaN             NaN  ...
# 1417                                                NaN             NaN  ...
#
#      foot  horse noexit sidewalk parkinglaneleft covered parkinglaneright  \
# 0     NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 1     NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 2     NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 3     NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 4     NaN    NaN    NaN      NaN             NaN     NaN              NaN
# ...   ...    ...    ...      ...             ...     ...              ...
# 1413  NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 1414  NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 1415  NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 1416  NaN    NaN    NaN      NaN             NaN     NaN              NaN
# 1417  NaN    NaN    NaN      NaN             NaN     NaN              NaN
#
#      destination maxweight motor_vehicle
# 0            NaN       NaN           NaN
# 1            NaN       NaN           NaN
# 2            NaN       NaN           NaN
# 3            NaN       NaN           NaN
# 4            NaN       NaN           NaN
# ...          ...       ...           ...
# 1413         NaN       NaN           NaN
# 1414         NaN       NaN           NaN
# 1415         NaN       NaN           NaN
# 1416         NaN       NaN           NaN
# 1417         NaN       NaN           NaN
#
# [1416 rows x 101 columns]

# %%
buiOtawa = pd.read_csv('buildingOtawa.csv', delimiter=";", encoding='latin-1')
buiOtawa = buiOtawa.iloc[:,1:]
ameOtawa = pd.read_csv('amenityOtawa.csv', delimiter=";", encoding='latin-1')
ameOtawa = ameOtawa.iloc[:,1:]
touOtawa = pd.read_csv('tourismOtawa.csv', delimiter=";", encoding='latin-1')
touOtawa = touOtawa.iloc[:,1:]
higOtawa = pd.read_csv('highwayOtawa.csv', delimiter=";", encoding='latin-1')
higOtawa = higOtawa.iloc[:,1:]
Otawa = buiOtawa.append(ameOtawa, ignore_index=True)
Otawa = Otawa.append(touOtawa, ignore_index = True)
Otawa = Otawa.append(higOtawa, ignore_index = True)
Otawa = Otawa.drop(Otawa[(Otawa['error'] != 'no') & (Otawa['error'] != 'yes')].index)
Otawa
# Out:
#         alpha                  conflict         beta error  addrhousenumber  \
# 0    building          building amenity       school   yes            261.0
# 1    building          building amenity       school   yes            350.0
# 2    building          building amenity       school   yes            362.0
# 3    building          building amenity       school   yes            334.0
# 4    building          building amenity       school   yes            340.0
# ..        ...                       ...          ...   ...              ...
# 588   highway  highway landuse building  residential    no              NaN
# 589   highway  highway landuse building  residential    no              NaN
# 590   highway  highway landuse building  residential    no              NaN
# 591   highway  highway landuse building  residential    no              NaN
# 592   highway  highway landuse building  residential    no              NaN
#
#            addrstreet building  buildinglevels          source addrpostcode  \
# 0    Buena Vista Road   school             3.0  City of Ottawa          NaN
# 1    Buena Vista Road   school             NaN  City of Ottawa      K1M 1C1
# 2     Mariposa Avenue   school             NaN  City of Ottawa          NaN
# 3     Mariposa Avenue   school             NaN  City of Ottawa          NaN
# 4     Mariposa Avenue   school             NaN  City of Ottawa          NaN
# ..                ...      ...             ...             ...          ...
# 588               NaN      NaN             NaN             NaN          NaN
# 589               NaN      NaN             NaN             NaN          NaN
# 590               NaN      NaN             NaN             NaN          NaN
# 591               NaN      NaN             NaN             NaN          NaN
# 592               NaN      NaN             NaN             NaN          NaN
#
#      ... service oneway winter_service traffic_signals traffic_signalssound  \
# 0    ...     NaN    NaN            NaN             NaN                  NaN
# 1    ...     NaN    NaN            NaN             NaN                  NaN
# 2    ...     NaN    NaN            NaN             NaN                  NaN
# 3    ...     NaN    NaN            NaN             NaN                  NaN
# 4    ...     NaN    NaN            NaN             NaN                  NaN
# ..   ...     ...    ...            ...             ...                  ...
# 588  ...     NaN    yes            NaN             NaN                  NaN
# 589  ...     NaN    yes            NaN             NaN                  NaN
# 590  ...     NaN    yes            NaN             NaN                  NaN
# 591  ...     NaN    yes            NaN             NaN                  NaN
# 592  ...     NaN    yes            NaN             NaN                  NaN
#
#     crossingisland bicycle horse  lit parkinglaneboth
# 0              NaN     NaN   NaN  NaN             NaN
# 1              NaN     NaN   NaN  NaN             NaN
# 2              NaN     NaN   NaN  NaN             NaN
# 3              NaN     NaN   NaN  NaN             NaN
# 4              NaN     NaN   NaN  NaN             NaN
# ..             ...     ...   ...  ...             ...
# 588            NaN     NaN   NaN  yes             NaN
# 589            NaN     NaN   NaN  NaN             NaN
# 590            NaN     NaN   NaN  NaN             NaN
# 591            NaN     NaN   NaN  NaN             NaN
# 592            NaN     NaN   NaN  yes             NaN
#
# [592 rows x 80 columns]

# %%
buiSantiagoChile = pd.read_csv('buildingSantiagoChile.csv', delimiter=";", encoding='latin-1')
buiSantiagoChile = buiSantiagoChile.iloc[:,1:]
ameSantiagoChile = pd.read_csv('amenitySantiagoChile.csv', delimiter=";", encoding='latin-1')
ameSantiagoChile = ameSantiagoChile.iloc[:,1:]
touSantiagoChile = pd.read_csv('tourismSantiagoChile.csv', delimiter=";", encoding='latin-1')
touSantiagoChile = touSantiagoChile.iloc[:,1:]
higSantiagoChile = pd.read_csv('highwaySantiagoChile.csv', delimiter=";", encoding='latin-1')
higSantiagoChile = higSantiagoChile.iloc[:,1:]
SantiagoChile = buiSantiagoChile.append(ameSantiagoChile, ignore_index=True)
SantiagoChile = SantiagoChile.append(touSantiagoChile, ignore_index = True)
SantiagoChile = SantiagoChile.append(higSantiagoChile, ignore_index = True)
SantiagoChile
# Out:
#         alpha                    conflict      beta error  addrcity  \
# 0    building            amenity building    school   yes  Lo Prado
# 1    building            amenity building    school   yes       NaN
# 2    building            amenity building    school   yes       NaN
# 3    building            amenity building    school   yes       NaN
# 4    building            amenity building    school   yes       NaN
# ..        ...                         ...       ...   ...       ...
# 974   highway  highway destination:symbol  motorway    no       NaN
# 975   highway  highway destination:symbol  motorway    no       NaN
# 976   highway  highway destination:symbol  motorway    no       NaN
# 977   highway  highway destination:symbol  motorway    no       NaN
# 978   highway  highway destination:symbol  motorway    no       NaN
#
#      addrhousenumber         addrstreet amenity building  \
# 0             6135.0  Avenida San Pablo  school   school
# 1                NaN                NaN     NaN   school
# 2                NaN                NaN     NaN   school
# 3                NaN                NaN     NaN   school
# 4                NaN                NaN     NaN   school
# ..               ...                ...     ...      ...
# 974              NaN                NaN     NaN      NaN
# 975              NaN                NaN     NaN      NaN
# 976              NaN                NaN     NaN      NaN
# 977              NaN                NaN     NaN      NaN
# 978              NaN                NaN     NaN      NaN
#
#                                  name  ... tunnel covered  bicycle foot  \
# 0    Escuela BÃ¡sica My Garden School  ...    NaN     NaN      NaN  NaN
# 1                                 NaN  ...    NaN     NaN      NaN  NaN
# 2                                 NaN  ...    NaN     NaN      NaN  NaN
# 3                                 NaN  ...    NaN     NaN      NaN  NaN
# 4                                 NaN  ...    NaN     NaN      NaN  NaN
# ..                                ...  ...    ...     ...      ...  ...
# 974                 Autopista Central  ...    NaN     NaN       no   no
# 975                 Autopista Central  ...    NaN     NaN       no   no
# 976                 Autopista Central  ...    NaN     NaN       no   no
# 977                 Autopista Central  ...    NaN     NaN       no   no
# 978                 Autopista Central  ...    NaN     NaN       no   no
#
#                                          official_name  ref maxheight  \
# 0                                                  NaN  NaN       NaN
# 1                                                  NaN  NaN       NaN
# 2                                                  NaN  NaN       NaN
# 3                                                  NaN  NaN       NaN
# 4                                                  NaN  NaN       NaN
# ..                                                 ...  ...       ...
# 974  Longitudinal Norte, Sector: Av. Bernardo O'Hig...  5.0       4.4
# 975  Longitudinal Norte, Sector: Av. Bernardo O'Hig...  5.0       4.4
# 976  Longitudinal Norte, Sector: Av. Bernardo O'Hig...  5.0       NaN
# 977  Longitudinal Norte, Sector: Av. Bernardo O'Hig...  5.0       NaN
# 978  Longitudinal Norte, Sector: Av. Bernardo O'Hig...  5.0       4.4
#
#     destinationlanes         turnlanes Unnamed: 56
# 0                NaN               NaN         NaN
# 1                NaN               NaN         NaN
# 2                NaN               NaN         NaN
# 3                NaN               NaN         NaN
# 4                NaN               NaN         NaN
# ..               ...               ...         ...
# 974              NaN               NaN         NaN
# 975              NaN               NaN         NaN
# 976              NaN               NaN         NaN
# 977              NaN  |||merge_to_left         NaN
# 978              NaN  |||merge_to_left         NaN
#
# [979 rows x 103 columns]

# %%
buiRome = pd.read_csv('buildingRome.csv', delimiter=";", encoding='latin-1')
buiRome = buiRome.iloc[:,1:]
ameRome = pd.read_csv('amenityRome.csv', delimiter=";", encoding='latin-1')
ameRome = ameRome.iloc[:,1:]
touRome = pd.read_csv('tourismRome.csv', delimiter=";", encoding='latin-1')
touRome = touRome.iloc[:,1:]
higRome = pd.read_csv('highwayRome.csv', delimiter=";", encoding='latin-1')
higRome = higRome.iloc[:,1:]
Rome = buiRome.append(ameRome, ignore_index=True)
Rome = Rome.append(touRome, ignore_index = True)
Rome = Rome.append(higRome, ignore_index = True)
Rome
# Out:
#          alpha                  conflict         beta error  \
# 0     building         building historic       church   yes
# 1     building         building historic       church   yes
# 2     building         building historic       church   yes
# 3     building         building historic       church   yes
# 4     building         building historic       church   yes
# ...        ...                       ...          ...   ...
# 1817   highway           highway landuse  residential    no
# 1818   highway           highway landuse  residential    no
# 1819   highway           highway landuse  residential    no
# 1820   highway           highway landuse  residential    no
# 1821   highway  public_transport railway     platform    no
#
#                addrstreet           amenity building denomination  \
# 0       Via del Quirinale  place_of_worship   church     catholic
# 1                     NaN  place_of_worship   church     catholic
# 2                     NaN  place_of_worship   church     catholic
# 3     Via Venti Settembre  place_of_worship   church     catholic
# 4                     NaN  place_of_worship   church     lutheran
# ...                   ...               ...      ...          ...
# 1817                  NaN               NaN      NaN          NaN
# 1818                  NaN               NaN      NaN          NaN
# 1819                  NaN               NaN      NaN          NaN
# 1820                  NaN               NaN      NaN          NaN
# 1821                  NaN               NaN      NaN          NaN
#
#                                          name   religion  ...  hgv  \
# 0                      Chiostro del Borromini  christian  ...  NaN
# 1       Sant'Ignazio di Loyola a Campo Marzio  christian  ...  NaN
# 2     Santa Susanna alle Terme di Diocleziano  christian  ...  NaN
# 3                  Santa Maria della Vittoria  christian  ...  NaN
# 4                  Chiesa evangelica luterana  christian  ...  NaN
# ...                                       ...        ...  ...  ...
# 1817                       Via del Mascherino        NaN  ...  NaN
# 1818                         Via di Belvedere        NaN  ...  NaN
# 1819                           Borgo Vittorio        NaN  ...  NaN
# 1820                           Borgo Vittorio        NaN  ...  NaN
# 1821                   Risorgimento/S. Pietro        NaN  ...  NaN
#
#      accessconditional motorcar footway service colonnade  \
# 0                  NaN      NaN     NaN     NaN       NaN
# 1                  NaN      NaN     NaN     NaN       NaN
# 2                  NaN      NaN     NaN     NaN       NaN
# 3                  NaN      NaN     NaN     NaN       NaN
# 4                  NaN      NaN     NaN     NaN       NaN
# ...                ...      ...     ...     ...       ...
# 1817               NaN      NaN     NaN     NaN       NaN
# 1818               NaN      NaN     NaN     NaN       NaN
# 1819               NaN      NaN     NaN     NaN       NaN
# 1820               NaN      NaN     NaN     NaN       NaN
# 1821               NaN      NaN     NaN     NaN       NaN
#
#       check_datetactile_paving parkingconditionboth horse  Unnamed: 107
# 0                          NaN                  NaN   NaN           NaN
# 1                          NaN                  NaN   NaN           NaN
# 2                          NaN                  NaN   NaN           NaN
# 3                          NaN                  NaN   NaN           NaN
# 4                          NaN                  NaN   NaN           NaN
# ...                        ...                  ...   ...           ...
# 1817                       NaN                  NaN   NaN           NaN
# 1818                       NaN                  NaN   NaN           NaN
# 1819                       NaN                  NaN   NaN           NaN
# 1820                       NaN                  NaN   NaN           NaN
# 1821                       NaN                  NaN   NaN           NaN
#
# [1822 rows x 255 columns]

# %%
buiWuhan = pd.read_csv('buildingWuhan.csv', delimiter=";", encoding='latin-1')
buiWuhan = buiWuhan.iloc[:,1:]
ameWuhan = pd.read_csv('amenityWuhan.csv', delimiter=";", encoding='latin-1')
ameWuhan = ameWuhan.iloc[:,1:]
touWuhan = pd.read_csv('tourismWuhan.csv', delimiter=";", encoding='latin-1')
touWuhan = touWuhan.iloc[:,1:]
higWuhan = pd.read_csv('highwayWuhan.csv', delimiter=";", encoding='latin-1')
higWuhan = higWuhan.iloc[:,1:]
Wuhan = buiWuhan.append(ameWuhan, ignore_index=True)
Wuhan = Wuhan.append(touWuhan, ignore_index = True)
Wuhan = Wuhan.append(higWuhan, ignore_index = True)
Wuhan = Wuhan.drop(Wuhan[(Wuhan['error'] != 'no') & (Wuhan['error'] != 'yes')].index)
Wuhan
# Out:
#          alpha          conflict          beta error    building  \
# 0     building  landuse building    commercial   yes  commercial
# 1     building  landuse building    commercial   yes  commercial
# 2     building  landuse building    commercial   yes  commercial
# 3     building  landuse building    commercial   yes  commercial
# 4     building  landuse building    commercial   yes  commercial
# ...        ...               ...           ...   ...         ...
# 2334   highway   landuse highway  construction    no         NaN
# 2335   highway   landuse highway  construction    no         NaN
# 2336   highway   landuse highway  construction    no         NaN
# 2337   highway   landuse highway  construction    no         NaN
# 2338   highway   landuse highway  construction    no         NaN
#
#                     name  height addrcity addrdistrict addrhousenumber  ...  \
# 0      å
# è°·éèæ¸¯A1     NaN      NaN          NaN             NaN  ...
# 1     å
# è°·éèæ¸¯A10    72.0      NaN          NaN             NaN  ...
# 2     å
# è°·éèæ¸¯A11    72.0      NaN          NaN             NaN  ...
# 3     å
# è°·éèæ¸¯A12    60.0      NaN          NaN             NaN  ...
# 4     å
# è°·éèæ¸¯A13    60.0      NaN          NaN             NaN  ...
# ...                  ...     ...      ...          ...             ...  ...
# 2334                 NaN     NaN      NaN          NaN             NaN  ...
# 2335                 NaN     NaN      NaN          NaN             NaN  ...
# 2336                 NaN     NaN      NaN          NaN             NaN  ...
# 2337           äºå½©è·¯     NaN      NaN          NaN             NaN  ...
# 2338                 NaN     NaN      NaN          NaN             NaN  ...
#
#      bicycle foot  horse embankment  maxheight  motor_vehicle noname  lit  \
# 0        NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 1        NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 2        NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 3        NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 4        NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# ...      ...  ...    ...        ...        ...            ...    ...  ...
# 2334     NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 2335     NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 2336     NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 2337     NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
# 2338     NaN  NaN    NaN        NaN        NaN            NaN    NaN  NaN
#
#      secondary motorroad
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ...        ...       ...
# 2334       NaN       NaN
# 2335       NaN       NaN
# 2336       NaN       NaN
# 2337       NaN       NaN
# 2338       NaN       NaN
#
# [2337 rows x 82 columns]

# %%
Brussel.to_csv('Brussel.csv', index = False)

# %% [markdown]
# ### We create the function.

# %%
def error(dataset, deli):
    data = pd.read_csv(dataset, delimiter = deli)
    # data = pd.read_csv('Wuhan.csv', delimiter = ',', encoding='latin-1')
    index = data.iloc[:,0]
    obj = data['error']
    data = data[['alpha','beta']]
    data1 = list(data['alpha'])
    data2 = list(data['beta'])
    file = open("dict_all.obj",'rb')
    dict_all_loaded = pickle.load(file)
    file = open("target.obj",'rb')
    dict_obj_loaded = pickle.load(file)
    file.close()
    file.close()
    for col in data.columns[0:2]:
            data.replace(dict_all_loaded[col], inplace=True)
    data['aux1']=data1 
    data['aux2']=data2        
    def get_key(val):
        for key, value in dict_obj_loaded.items():
             if val == value:
                 return key
        return "key doesn't exist"
    rf = joblib.load("./random_forest.joblib")
    lista = []
    for i in range(len(data)):        
            if data.iloc[i,1] not in list(dict_all_loaded.get('beta').values()):
                lista.append(np.array([dict_obj_loaded['yes']]))
            else:
                pred = pd.DataFrame(data.iloc[i,0:2]).T
                a = rf.predict(pred)
                lista.append(a)

    lista1=[]
    for i in lista: lista1.append(i[0])
    obj1 = [dict_obj_loaded[x] for x in obj]
    list2 = []
    for i in lista1:
        list2.append(get_key(i))
    df = {'ID': index, 'Error': list2, 'Error real': obj}
    df = pd.DataFrame(df)
    print(df)
    print(accuracy_score(lista1,obj1))
    print(f1_score(lista1,obj1))
    print(confusion_matrix(obj1, lista1))

# %% [markdown]
# ### We check the quality of the results in Wuhan example.

# %%
Wuhan = Wuhan.drop(Wuhan[(Wuhan['error'] != 'no') & (Wuhan['error'] != 'yes')].index)
Wuhan.to_csv('Wuhan.csv', index = False)  
error('Wuhan.csv', ',')
# Out:
#             ID Error Error real
# 0     building   yes        yes
# 1     building   yes        yes
# 2     building   yes        yes
# 3     building   yes        yes
# 4     building   yes        yes
# ...        ...   ...        ...
# 2332   highway    no         no
# 2333   highway    no         no
# 2334   highway    no         no
# 2335   highway    no         no
# 2336   highway    no         no
#
# [2337 rows x 3 columns]
# 0.8981600342319213
# 0.782051282051282
# [[1672  238]
#  [   0  427]]
